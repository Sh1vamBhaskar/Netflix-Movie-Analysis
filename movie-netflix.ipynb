# %% [markdown]
# **To get details of the dataset**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df= pd.read_csv('/kaggle/input/movie-title/titles.csv')
df.head( )
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5850 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5850 non-null   object
#  3   description           5832 non-null   object
#  4   release_year          5850 non-null   int64
#  5   age_certification     3231 non-null   object
#  6   runtime               5850 non-null   int64
#  7   genres                5850 non-null   object
#  8   production_countries  5850 non-null   object
#  9   seasons               2106 non-null   float64
#  10  imdb_id               5447 non-null   object
#  11  imdb_score            5368 non-null   float64
#  12  imdb_votes            5352 non-null   float64
#  13  tmdb_popularity       5759 non-null   float64
#  14  tmdb_score            5539 non-null   float64
# ...

# %% [markdown]
# **Cleaning the Data**

# %%
df.isna().sum()
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %% [markdown]
# No Misiing or NULL value found .

# %%
df['genres'].head()
# Out:
# 5                                ['comedy', 'european']
# 26                                           ['comedy']
# 35                                           ['comedy']
# 44                ['scifi', 'action', 'crime', 'drama']
# 45    ['animation', 'family', 'comedy', 'fantasy', '...
# Name: genres, dtype: object

# %% [markdown]
# **checking for duplicated data**

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   1667.000000  1667.000000  1667.000000  1667.000000  1.667000e+03
# mean    2017.355729    38.767846     2.337732     6.991482  1.970630e+04
# std        5.281628    16.944673     2.922864     1.067871  7.666425e+04
# min     1969.000000     0.000000     1.000000     2.000000  5.000000e+00
# 25%     2016.000000    25.000000     1.000000     6.400000  6.060000e+02
# 50%     2019.000000    41.000000     1.000000     7.100000  2.270000e+03
# 75%     2020.000000    49.000000     3.000000     7.700000  8.862000e+03
# max     2022.000000   178.000000    42.000000     9.500000  1.775990e+06
#
#        tmdb_popularity   tmdb_score
# count      1667.000000  1667.000000
# mean         31.121982     7.464122
# std          96.320717     1.049718
# min           0.600000     1.000000
# 25%           4.375500     7.000000
# 50%           9.850000     7.500000
# 75%          24.539500     8.100000
# ...

# %% [markdown]
# **Summary**
#
# 1. We have a dataframe consisting of total 5850 rows and 15 columns.
# 2. Our datset looks little bit tidy with no Nans and nor duplicated values.
# 3. Description , age certification , production countries and seasons won't be so useful in our analysis so we will be dropping them.
# 4. imdb votes can be better categorized for proper analysis.
# 5. Genres are having extra space after comma that need to be removed to make it look clean.

# %%
df.head()
# Out:
#          id                             title  type  \
# 5   ts22164      Monty Python's Flying Circus  SHOW
# 26  ts45948  Monty Python's Fliegender Zirkus  SHOW
# 35  ts20681                          Seinfeld  SHOW
# 44  ts22082                      Knight Rider  SHOW
# 45  ts21715                  Thomas & Friends  SHOW
#
#                                           description  release_year  \
# 5   A British sketch comedy series with the shows ...          1969
# 26  Monty Python's Fliegender Zirkus consisted of ...          1972
# 35  A stand-up comedian and his three offbeat frie...          1989
# 44  Michael Long, an undercover police officer, is...          1982
# 45  Thomas & Friends is a British children's telev...          1984
#
#    age_certification  runtime  \
# 5              TV-14       30
# 26             TV-MA       43
# 35             TV-PG       24
# 44             TV-PG       51
# 45              TV-Y       10
#
# ...

# %% [markdown]
# --------    **DATA CLEANING INITIATED**    --------
#
#
# *Dropping "Description" , " age certification" ,"production countries" ,"seasons"*

# %%
#making list of Colmn to be dropped
colm = ['description','age_certification','production_countries','seasons']

# dropping columns and confirming changes
df.drop(colm, axis = 1, inplace = True)
df.columns
# Out:
# Index(['id', 'title', 'type', 'release_year', 'runtime', 'genres', 'imdb_id',
#        'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='object')

# %%
df.head()
# Out:
#          id                             title  type  release_year  runtime  \
# 5   ts22164      Monty Python's Flying Circus  SHOW          1969       30
# 26  ts45948  Monty Python's Fliegender Zirkus  SHOW          1972       43
# 35  ts20681                          Seinfeld  SHOW          1989       24
# 44  ts22082                      Knight Rider  SHOW          1982       51
# 45  ts21715                  Thomas & Friends  SHOW          1984       10
#
#                                                genres    imdb_id  imdb_score  \
# 5                              ['comedy', 'european']  tt0063929         8.8
# 26                                         ['comedy']  tt0202477         8.1
# 35                                         ['comedy']  tt0098904         8.9
# 44              ['scifi', 'action', 'crime', 'drama']  tt0083437         6.9
# 45  ['animation', 'family', 'comedy', 'fantasy', '...  tt0086815         6.5
#
#     imdb_votes  tmdb_popularity  tmdb_score
# ...

# %% [markdown]
# **categorizing imdb_score column**
#
# We would cut the "imdb_votes" values and make 4 categories: popular average
# below_avg not_popular to describe it more using catigorize_col() function
# provided above.

# %%
coding for popular , not popular will be done here

# %% [markdown]
# **we'd split genres into a list and then
# explode our dataframe to have only one
# genre per row for ezch movie**

# %%
# split the strings into lists
df['genres'] = df['genres'].str.split(', ')
# explode the lists
df = df.explode('genres').reset_index(drop=True)
df.head()
